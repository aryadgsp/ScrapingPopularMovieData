# %%
import pandas as pd

# %%
data = pd.read_csv('movie_data_new.csv')
data.head()
# Out:
#                                Title Release Date  Adult  \
# 0                     Evil Dead Rise   2023-04-12  False
# 1  Ant-Man and the Wasp: Quantumania   2023-02-15  False
# 2        The Super Mario Bros. Movie   2023-04-05  False
# 3                The Pope's Exorcist   2023-04-05  False
# 4     Guardians of the Galaxy Vol. 3   2023-05-03  False
#
#                  Genre IDs                                           Overview  \
# 0             [27, 53, 14]  Three siblings find an ancient vinyl that give...
# 1            [28, 12, 878]  Super-Hero partners Scott Lang and Hope van Dy...
# 2  [16, 10751, 12, 14, 35]  While working underground to fix a water main,...
# 3             [27, 53, 14]  Father Gabriele Amorth, Chief Exorcist of the ...
# 4            [878, 12, 28]  Peter Quill, still reeling from the loss of Ga...
#
#    Popularity  Vote Average  Vote Count Original Language  \
# 0    5030.612           7.1        1017                en
# ...

# %%
data.shape
# Out:
# (9981, 14)
